# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
display(customer_df.head())
display(customer_df.shape)
display(customer_df.info())
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.columns = customer_df.columns.str.lower().str.replace(' ','_')
display(customer_df.head(2))
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# ...

# %%
customer_df['effective_to_date']=pd.to_datetime(customer_df['effective_to_date'])
display(customer_df['effective_to_date'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9134 entries, 0 to 9133
# Series name: effective_to_date
# Non-Null Count  Dtype
# --------------  -----
# 9134 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 71.5 KB
# None

# %%
customer_df.isnull().sum()/customer_df.shape[0]
# Out:
# customer                         0.0
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64

# %%
def cont_disc(df):
    continuous = pd.DataFrame()
    discrete = pd.DataFrame()
    for col in df:
        if df[col].nunique() > 15:
            continuous[col] = df[col]
        elif df[col].nunique() <= 15:
            discrete[col] = df[col]
    return [continuous, discrete]

# %%
continuous=cont_disc(customer_df)[0]
discrete=cont_disc(customer_df)[1]

# %%
display(continuous.head(3))
print(continuous.shape)
# Out:
#   customer  customer_lifetime_value effective_to_date  income  \
# 0  BU79786              2763.519279        2011-02-24   56274
# 1  QZ44356              6979.535903        2011-01-31       0
# 2  AI49188             12887.431650        2011-02-19   48767
#
#    monthly_premium_auto  months_since_last_claim  \
# 0                    69                       32
# 1                    94                       13
# 2                   108                       18
#
#    months_since_policy_inception  total_claim_amount
# 0                              5          384.811147
# 1                             42         1131.464935
# 2                             38          566.472247
# (9134, 8)

# %%
display(discrete.head(3))
print(discrete.shape)
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
#
#   location_code marital_status  number_of_open_complaints  number_of_policies  \
# 0      Suburban        Married                          0                   1
# 1      Suburban         Single                          0                   8
# 2      Suburban        Married                          0                   2
#
#       policy_type        policy renew_offer_type sales_channel  vehicle_class  \
# 0  Corporate Auto  Corporate L3           Offer1         Agent   Two-Door Car
# 1   Personal Auto   Personal L3           Offer3         Agent  Four-Door Car
# 2   Personal Auto   Personal L3           Offer1         Agent   Two-Door Car
#
#   vehicle_size
# 0      Medsize
# 1      Medsize
# 2      Medsize
# ...

# %%
categorical= customer_df.select_dtypes(include=['object'])
categorical.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %%
def needs_cleaning(df):
    to_clean = pd.DataFrame()
    cleaned = pd.DataFrame()
    for col in df:
        if df[col].nunique() > 5:
            to_clean[col] = df[col]
        elif df[col].nunique() <= 5:
            cleaned[col] = df[col]
    return [to_clean, cleaned]

# %%
to_clean=needs_cleaning(categorical)[0]
cleaned=needs_cleaning(categorical)[1]

# %%
display(to_clean.head())
# Out:
#   customer        policy  vehicle_class
# 0  BU79786  Corporate L3   Two-Door Car
# 1  QZ44356   Personal L3  Four-Door Car
# 2  AI49188   Personal L3   Two-Door Car
# 3  WW63253  Corporate L2            SUV
# 4  HB64268   Personal L1  Four-Door Car

# %%
for col in to_clean:
    display(to_clean[col].value_counts())
# Out:
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: customer, Length: 9134, dtype: int64
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: policy, dtype: int64
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: vehicle_class, dtype: int64

# %% [markdown]
# For the columns "policy" and "vehicle_class" i would agregate some values, f.e. agregate all policy under their type(personal, corporate or special) while for vehicle class, either grouping in just cars and SUV, or grouping luxury and sports car into a single value.

# %% [markdown]
# Regarding customer id, since it's a unique value akin to an index, it shouldn't be important and i would drop it before training a model
